# %% [raw]
# either
# pip install beautifulsoup4
#
# or
# conda install -c anaconda beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# see https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Let's explore a snippet of HTML:

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %% [markdown]
# use BeautifulSoup to parse the HTML text

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
#print(soup.prettify())

# %% [markdown]
# now we can inspect components of the HTML

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %% [markdown]
# extract all the URLs found within a page's `<a>` tags:

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
import requests

# %%
resp = requests.get('https://www.kdnuggets.com/datasets/index.html')
resp.text
# Out:
# '<!DOCTYPE html>\n<html xmlns="https://www.w3.org/1999/xhtml" lang="en-US">\n<head profile="https://gmpg.org/xfn/11"><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><script>if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\\/7\\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]nowprocket/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?nowprocket=1"}else{document.location.href=href.replace("#","?nowprocket=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&nowprocket=1"}else{document.location.href=href.replace("#","&nowprocket=1#")}}}}</script><script>class RocketLazyLoadScripts{constructor(){this.triggerEvents=["keydown","mousedown","mousemove","touchmove","touchstart","touchend","wheel"],this.userEventHandler=this._triggerListener.bind(this),this.touchStartHandler=this._onTouchStart.bind(this),this.touchMoveHandler=this._onTouchMove.bind(this),this.touchEndHandler=this._onTouchEnd.bind(this),this.clickHandler=this._onClick.bind(this),this.interceptedClicks=[],window.addEventListener("pageshow",(e=>{this.persisted=e.persisted})),window.addEventListener("DOMContentLoaded",(()=>{this._preconnect3rdParties()})),this.delayedScripts={normal:[],async:[],defer:[]},this.allJQueries=[]}_addUserInteractionListener(e){document.hidden?e._triggerListener():(this.triggerEvents.forEach((t=>window.addEventListener(t,e.userEventHandler,{passive:!0}))),window.addEventListener("touchstart",e.touchStartHandler,{passive:!0}),window.addEventListener("mousedown",e.touchStartHandler),document.addEventListener("visibilitychange",e.userEventHandler))}_removeUserInteractionListener(){this.triggerEvents.forEach((e=>window.removeEventListener(e,this.userEventHandler,{passive:!0}))),document.removeEventListener("visibilitychange",this.userEventHandler)}_onTouchStart(e){"HTML"!==e.target.tagName&&(window.addEventListener("touchend",this.touchEndHandler),window.addEventListener("mouseup",this.touchEndHandler),window.addEventListener("touchmove",this.touchMoveHandler,{passive:!0}),window.addEventListener("mousemove",this.touchMoveHandler),e.target.addEventListener("click",this.clickHandler),this._renameDOMAttribute(e.target,"onclick","rocket-onclick"))}_onTouchMove(e){window.removeEventListener("touchend",this.touchEndHandler),window.removeEventListener("mouseup",this.touchEndHandler),window.removeEventListener("touchmove",this.touchMoveHandler,{passive:!0}),window.removeEventListener("mousemove",this.touchMoveHandler),e.target.removeEventListener("click",this.clickHandler),this._renameDOMAttribute(e.target,"rocket-onclick","onclick")}_onTouchEnd(e){window.removeEventListener("touchend",this.touchEndHandler),window.removeEventListener("mouseup",this.touchEndHandler),window.removeEventListener("touchmove",this.touchMoveHandler,{passive:!0}),window.removeEventListener("mousemove",this.touchMoveHandler)}_onClick(e){e.target.removeEventListener("click",this.clickHandler),this._renameDOMAttribute(e.target,"rocket-onclick","onclick"),this.interceptedClicks.push(e),e.preventDefault(),e.stopPropagation(),e.stopImmediatePropagation()}_replayClicks(){window.removeEventListener("touchstart",this.touchStartHandler,{passive:!0}),window.removeEventListener("mousedown",this.touchStartHandler),this.interceptedClicks.forEach((e=>{e.target.dispatchEvent(new MouseEvent("click",{view:e.view,bubbles:!0,cancelable:!0}))}))}_renameDOMAttribute(e,t,n){e.hasAttribute&&e.hasAttribute(t)&&(event.target.setAttribute(n,event.target.getAttribute(t)),event.target.removeAttribute(t))}_triggerListener(){this._removeUserInteractionListener(this),"loading"===document.readyState?document.addEventListener("DOMContentLoaded",this._loadEverythingNow.bind(this)):this._loadEverythingNow()}_preconnect3rdParties(){let e=[];document.querySelectorAll("script[type=rocketlazyloadscript]").forEach((t=>{if(t.hasAttribute("src")){const n=new URL(t.src).origin;n!==location.origin ...

# %%
kd_soup = BeautifulSoup(resp.text, 'html.parser')

# %%
for link in kd_soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /news/index.html
# /news/index.html
# /news/top-stories.html
# https://www.kdnuggets.com/news/submissions.html
# https://www.kdnuggets.com/about/index.html
# https://www.kdnuggets.com/topic
# https://www.kdnuggets.com/tag/artificial-intelligence
# https://www.kdnuggets.com/tag/career-advice
# https://www.kdnuggets.com/tag/computer-vision
# https://www.kdnuggets.com/tag/data-science
# https://www.kdnuggets.com/tag/machine-learning
# https://www.kdnuggets.com/tag/natural-language-processing
# https://www.kdnuggets.com/tag/news
# https://www.kdnuggets.com/tag/programming
# https://www.kdnuggets.com/tag/python
# https://www.kdnuggets.com/tag/sql
# https://www.kdnuggets.com/datasets/index.html
# https://www.kdnuggets.com/courses/index.html
# https://www.kdnuggets.com/education/online.html
# /education/analytics-data-mining-certificates.html
# /webcasts/index.html
# https://www.kdnuggets.com/meetings/index.html
# /meetings/index.html
# /jobs/index.html
# /software/index.html
# https://www.facebook.com/kdnuggets
# https://twitter.com/kdnuggets
# https://www.linkedin.com/groups/54257/
# #boxzilla-138215
# https://www.kdnuggets.com/news/subscribe.html
# https://worlddata.ai/partners/kdnuggets
# government-local-public.html
# api-hub-marketplace-platform.html
# https://toolbox.google.com/datasetsearch
# /datasets/worlddata-ai.html
# /2021/05/awesome-list-datasets.html
# http://anacode.de/
# https://appen.com/resources/datasets/
# http://www.assetmacro.com/market-data
# https://github.com/caesar0301/awesome-public-datasets
# https://aws.amazon.com/publicdatasets/
# http://blog.bigml.com/2013/02/28/data-data-data-thousands-of-public-data-sources/#comment-7538
# http://www.jcheminf.com/content/pdf/1758-2946-1-21.pdf
# https://www.usa.gov/About/developer-resources/1usagov.shtml
# http://www.data.gc.ca/
# http://www.causality.inf.ethz.ch/repository.php
# https://www.tacc.utexas.edu/resources/data-storage/#corral
# http://www.creditriskanalytics.net/
# http://shop.oreilly.com/product/0636920018254.do
# http://datacatalogs.org/
# https://data.gov.uk
# http://data.london.gov.uk/
# https://www.data.gov/education
# http://datamarket.com/
# http://datamob.org/
# http://www.data-planet.com/
# http://www.datasets.co/
# http://datasf.org/
# http://dataferrett.census.gov/
# http://www.cs.toronto.edu/~delve
# http://inforumweb.umd.edu/econdata/econdata.html
# https://data.world/
# https://www.cs.cmu.edu/~enron/
# http://data.europeana.eu/
# http://www.fedstats.gov/
# http://fimi.cs.helsinki.fi/
# http://fisher.osu.edu/fin/fdf/osudata.htm
# http://www.guardian.co.uk/news/datablog/2013/apr/12/gdelt-global-database-events-location
# https://generated.photos/datasets
# https://www.ncbi.nlm.nih.gov/geo/
# http://geodacenter.asu.edu/datalist/
# http://ngrams.googlelabs.com/datasets
# http://www.grainmarketresearch.com
# http://endb-consolidated.aihit.com/datasets.htm
# http://www.icwsm.org/2009/data/
# http://infochimps.org/
# http://www.investorlinks.com
# https://public.jmp.com/featured?utm_source=kdnuggets&utm_medium=advertisement&utm_campaign=datasetlisting
# https://www.kaggle.com/datasets
# http://www.sigkdd.org/kddcup/index.php
# http://konect.uni-koblenz.de/
# https://www.w3.org/wiki/SweoIG/TaskForces/CommunityProjects/LinkingOpenData
# https://www.lovethesales.com/press/data-request
# https://www.lyst.com/news/lyst-data-request/
# http://labrosa.ee.columbia.edu/millionsong/
# http://www-genome.wi.mit.edu/cgi-bin/cancer/datasets.cgi
# http://mldata.org
# https://data.nasdaq.com/
# https://www.archive-it.org/
# http://nssdc.gsfc.nasa.gov
# http://www.networkrepository.com/
# http://census.okfn.org/
# http://opendata.socrata.com/
# http://www.opensourcesports.com/
# http://www.delicious.com/pskomoroch/dataset
# http://www.pubgene.org/
# https://www.quandl.com/
# http://www.econ.yale.edu/~shiller/data.htm
# http://genome-www5.stanford.edu/MicroArray/SMD/
# http://datascientistinsights.com/2013/02/02/data-monetization-road-paved-on-top-of-data-sets/
# http://www.nd.edu/~oss/Data/data.html
# https://sports-statistics.com/
# http://lib.stat.cmu.edu/datasets/
# http://robjhyndman.com/TSDL/
# https://www.vhinny.com/about
# http://hcil.cs.umd.edu/localphp/hcil/vast/archive/viewbm.php
# http://kdd.ics.uci.edu/
# https://archive.ics.uci.edu/ml/
# http://www.cs.ucr.edu/~eamonn/time_series_data/
# https://www.getthedata.com/open-postcode-geo
# https://www.census.gov/
# http://webdatacommons.org/
# https://webhose.io/datasets
# http://wikiposit.org/
# http://blog.wolframalpha.com/2010/06/29/disease-and-patient-level-statistics-with-wolframalpha/
# https://worlddata.ai/partners/kdnuggets
# http://webscope.sandbox.yahoo.com/catalog.php
# https://www.yelp.com/dataset
# /competitions/index.html
# /datasets/kddcup.html
# /news/index.html
# https://www.kdnuggets.com/2022/04/domino-join-data-science-leaders-rev-3.html
# https://www.kdnuggets.com/2022/04/artificial-intelligence-transform-data-integration.html
# https://www.kdnuggets.com/2022/04/prioritizing-data-science-models-production.html
# https://www.kdnuggets.com/2021/09/determine-best-fitting-data-distribution-python.html
# https://www.kdnuggets.com/2022/04/sigopt-guide-iteratively-tuning-gnns.html
# https://www.kdnuggets.com/2022/04/top-youtube-channels-learning-data-science.html
# /2022/04/python-libraries-data-scientists-know-2022.html
# /2022/04/python-libraries-data-scientists-know-2022.html
# /2020/01/decision-tree-algorithm-explained.html
# /2020/06/naive-bayes-algorithm-everything.html
# /2022/03/many-data-scientists-quitting-jobs.html
# /2021/05/top-programming-languages.html
# https://www.kdnuggets.com/2022/04/top-youtube-channels-learning-data-science.html
# https://www.kdnuggets.com/2022/04/deepmind-alphacode-replace-programmers.html
# https://www.kdnuggets.com/2022/04/top-posts-week-0411-0417.html
# https://www.kdnuggets.com/2022/04/deploy-machine-learning-web-app-heroku.html
# https://www.kdnuggets.com/2020/08/5-different-ways-load-data-python.html
# https://www.kdnuggets.com/2022/04/write-engaging-technical-blogs.html
# https://www.kdnuggets.com/2022/04/manning-data-privacy-learn-implement-technical-privacy-solutions-tools-scale.html
# https://www.kdnuggets.com/2022/04/data-science-interview-guide-part-2-interview-resources.html
# https://www.kdnuggets.com/2021/10/simple-question-answering-web-app-hugging-face-pipelines.html
# https://www.kdnuggets.com/2022/04/ace-data-science-assessment-test-automatic-eda-tools.html
# /news/subscribe.html
# https://kdnuggets.local/news/privacy-policy.html
# /
# /about/index.html
# /contact.html
# /news/privacy-policy.html
# /terms-of-service.html
# /news/subscribe.html
# https://kdnuggets.local/news/privacy-policy.html
# /news/subscribe.html
# https://kdnuggets.local/news/privacy-policy.html
